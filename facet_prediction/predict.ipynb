# %%
from transformers import pipeline

appearance_text_classifier = pipeline("text-classification", model="DaneNguyen/Label-classifier")

results = appearance_text_classifier(raw_dataset['test']['refer_text'])
for res in results:
    print(res)
# Out:
# {'label': 'method', 'score': 0.980759859085083}
# {'label': 'method', 'score': 0.6443973183631897}
# {'label': 'method', 'score': 0.9777945280075073}
# {'label': 'method', 'score': 0.7474862933158875}
# {'label': 'method', 'score': 0.978004515171051}
# {'label': ' aim', 'score': 0.2883966565132141}
# {'label': 'method', 'score': 0.9777945280075073}
# {'label': 'method', 'score': 0.978004515171051}
# {'label': 'method', 'score': 0.9741541743278503}
# {'label': 'result', 'score': 0.4861385226249695}
# {'label': 'method', 'score': 0.8636013269424438}
# {'label': 'method', 'score': 0.9162874817848206}
# {'label': 'method', 'score': 0.9750184416770935}
# {'label': 'method', 'score': 0.9777945280075073}
# {'label': 'result', 'score': 0.4861385226249695}
# {'label': 'method', 'score': 0.9809277653694153}
# {'label': 'method', 'score': 0.6443973183631897}
# {'label': 'method', 'score': 0.9809277653694153}
# {'label': 'method', 'score': 0.8962962627410889}
# ...
